# %%
from flask import Flask, request


app = Flask(__name__)

@app.route('/')
def index() :
    return '<h1>Hello World</h1>'

@app.route('/login', methods=['GET', 'POST'])
def login_db() :
    if request.method == 'POST' :
        login_id = request.form['login_id']  # request.form['보내주는 key값']
        login_pw = request.form['login_pw']
    print(login_id, login_pw)
    
    return  '로그인 페이지입니다.'

if __name__ == '__main__' :
    app.run(host='192.168.70.148', port=2050)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://192.168.70.148:2050
# Press CTRL+C to quit
# [2022-09-23 11:31:00,005] ERROR in app: Exception on /login [GET]
# Traceback (most recent call last):
#   File "C:\Users\AI\Anaconda3\envs\openCV\lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\AI\Anaconda3\envs\openCV\lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\AI\Anaconda3\envs\openCV\lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\AI\Anaconda3\envs\openCV\lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\AI\AppData\Local\Temp\ipykernel_10428\1628528321.py", line 14, in login_db
#     print(login_id, login_pw)
# UnboundLocalError: local variable 'login_id' referenced before assignment
# 192.168.70.148 - - [23/Sep/2022 11:31:00] "GET /login HTTP/1.1" 500 -
# 192.168.70.148 - - [23/Sep/2022 11:39:52] "GET / HTTP/1.1" 200 -
# 192.168.70.148 - - [23/Sep/2022 11:39:58] "GET /index.html HTTP/1.1" 404 -
# 192.168.70.148 - - [23/Sep/2022 11:42:28] "GET / HTTP/1.1" 200 -
# 192.168.70.148 - - [23/Sep/2022 11:42:33] "GET /index.html HTTP/1.1" 404 -
# 192.168.70.148 - - [23/Sep/2022 11:43:01] "POST /login HTTP/1.1" 200 -
# kmj2 1234
# 192.168.70.148 - - [23/Sep/2022 11:45:33] "POST /login HTTP/1.1" 200 -
# kmj2 1234
# 192.168.70.148 - - [23/Sep/2022 11:45:37] "POST /login HTTP/1.1" 200 -
# 192.168.70.148 - - [23/Sep/2022 11:45:37] "GET /favicon.ico HTTP/1.1" 404 -
# kmj2 1234
# 192.168.70.148 - - [23/Sep/2022 11:46:03] "POST /login HTTP/1.1" 200 -
# 192.168.70.148 - - [23/Sep/2022 11:46:03] "GET /favicon.ico HTTP/1.1" 404 -
# kmj2 1234
# 192.168.70.148 - - [23/Sep/2022 11:47:52] "GET / HTTP/1.1" 200 -
# 192.168.70.148 - - [23/Sep/2022 11:47:57] "GET / HTTP/1.1" 200 -
# 192.168.70.148 - - [23/Sep/2022 11:48:03] "GET /index.html HTTP/1.1" 404 -
# [2022-09-23 11:48:12,244] ERROR in app: Exception on /login [GET]
# Traceback (most recent call last):
#   File "C:\Users\AI\Anaconda3\envs\openCV\lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\AI\Anaconda3\envs\openCV\lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\AI\Anaconda3\envs\openCV\lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\AI\Anaconda3\envs\openCV\lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\AI\AppData\Local\Temp\ipykernel_10428\1628528321.py", line 14, in login_db
#     print(login_id, login_pw)
# UnboundLocalError: local variable 'login_id' referenced before assignment
# 192.168.70.148 - - [23/Sep/2022 11:48:12] "GET /login HTTP/1.1" 500 -
# 192.168.70.148 - - [23/Sep/2022 11:49:58] "POST /login HTTP/1.1" 200 -
# kmj2 1234
# 192.168.70.148 - - [23/Sep/2022 11:50:01] "POST /login HTTP/1.1" 200 -
# kmj2 12342
# 192.168.70.148 - - [23/Sep/2022 11:50:29] "GET / HTTP/1.1" 200 -
# [2022-09-23 11:50:34,098] ERROR in app: Exception on /login [GET]
# Traceback (most recent call last):
#   File "C:\Users\AI\Anaconda3\envs\openCV\lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\AI\Anaconda3\envs\openCV\lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\AI\Anaconda3\envs\openCV\lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\AI\Anaconda3\envs\openCV\lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\AI\AppData\Local\Temp\ipykernel_10428\1628528321.py", line 14, in login_db
#     print(login_id, login_pw)
# UnboundLocalError: local variable 'login_id' referenced before assignment
# 192.168.70.148 - - [23/Sep/2022 11:50:34] "GET /login HTTP/1.1" 500 -

# %% [markdown]
# ![image.png](attachment:image.png)
